# %%
import numpy as np
import pandas as pd
import sympy as sp

import matplotlib.pyplot as plt

# %%
init_a = 3
init_omega = 1.5
init_psi = 2

t = np.linspace(0,10, 1000)

true_func = init_a * np.sin(init_omega * t + init_psi)

# %%
plt.plot(t, true_func)
